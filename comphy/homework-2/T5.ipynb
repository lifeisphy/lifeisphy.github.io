# %%
from T4_auto_test import *
from Spline_Interpolation import cubic_spline_interpolation
import numpy as np 
from math import *
t=list(range(9))

x=lambda t:cos(t*pi/4)*(1-cos(t*pi/4))
y=lambda t:sin(t*pi/4)*(1-cos(t*pi/4))
ax,bx,cx,dx,fx=cubic_spline_interpolation(x,t)
ay,by,cy,dy,fy=cubic_spline_interpolation(y,t)
print(ax,bx,cx,dx)
print(ay,by,cy,dy)
# Out:
# [0.0, 0.20710678118654752, 6.123233995736765e-17, -1.2071067811865475, -2.0, -1.207106781186548, -1.8369701987210302e-16, 0.2071067811865476] [0.24560181949343135, 0.13011670457277985, -0.7660686377845506, -1.3084828405538624, -4.440892098500626e-16, 1.3084828405538622, 0.766068637784551, -0.13011670457277974] [0.0, -0.11548511492065153, -0.7807002274366789, 0.2382860246673672, 1.070196815886495, 0.2382860246673677, -0.7807002274366789, -0.1154851149206518] [-0.03849503830688384, -0.22173837083867579, 0.339662084034682, 0.2773035970730426, -0.2773035970730424, -0.3396620840346822, 0.22173837083867567, 0.03849503830688394]
# [0.0, 0.20710678118654752, 0.9999999999999999, 1.2071067811865475, 2.4492935982947064e-16, -1.2071067811865475, -1.0000000000000002, -0.20710678118654768] [0.03361162489122435, 0.5540970937771938, 0.75, -0.5540970937771936, -1.5336116248912242, -0.5540970937771943, 0.7499999999999999, 0.5540970937771941] [0.0, 0.5204854688859695, -0.3245825626631634, -0.9795145311140303, -3.5697123088426085e-16, 0.9795145311140304, 0.3245825626631637, -0.5204854688859696] [0.17349515629532317, -0.28168934384971095, -0.218310656150289, 0.32650484370467664, 0.3265048437046769, -0.2183106561502889, -0.28168934384971106, 0.1734951562953232]

# %%
ax1=plt.subplot(111,projection="polar")
sample_phi=np.linspace(0,2*pi,1000)
r = [1-cos(phi) for phi in sample_phi]
t_=np.linspace(0,8,1000)
rho=[sqrt(fx(ti)**2+fy(ti)**2) for ti in t_]
phi=[atan2(fy(ti),fx(ti)) for ti in t_]
# plt.plot(t_,[fx(i) for i in t_])
# plt.show()
ax1.plot(sample_phi,r,label="original")
ax1.plot(phi,rho,label="approximation")
plt.legend()
plt.show()
